# %%
from src.containers.evaluation_container import EvaluationContainer
from src.services.config.config_interface import DirConfig

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import math

# %%
container = EvaluationContainer('train001')
container.initialize()
# Out:
# [EvaluationContainer 2022-12-30 22:11:18] INFO Setup [EvaluationContainer]
# [ConfigService 2022-12-30 22:11:18] INFO Setup [ConfigService]
# [ConfigService 2022-12-30 22:11:18] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-12-30 22:11:18] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-12-30 22:11:18] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001')}
# [ConfigService 2022-12-30 22:11:18] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/outputs')}
# [ConfigService 2022-12-30 22:11:18] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions')}
# [ConfigService 2022-12-30 22:11:18] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/models')}
# [ConfigService 2022-12-30 22:11:18] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/figures')}
# [ConfigService 2022-12-30 22:11:18] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/optimize')}
# [ConfigService 2022-12-30 22:11:18] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train001.yaml
# =============== /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train001.yaml =================
# name: "test"
# seed: 77
# problem_type: regression
# target_name: gmv_28day
# treatment_name: treatment
# coupon_config:
#   variant_no_to_coupon_type:
#     0: "control"
#     1: "5% back"
#     2: "5% off"
#     3: "300yen off"
#     4: "10% off"
#     5: "10% back"
#     6: "15% off"
#
# preprocess_config:
#   test_size: 0.2
#
# model_config:
#   metalearner:
#     name: 's-learner' # s-learner, t-learner, x-learner, transformedoutcome, costconsious
#     params:
#       control_no: 0
#   basemodel:
#     name: 'lgbm' # lgbm, xgb, catboost, rf, mlp, linear, ridge, lasso, elasticnet, svr
#     params:
#       learning_rate: 0.1
#       n_estimators: 500
#       n_jobs: -1
#       # verbose: 100
#
# feature_config:
#   feature_names:
#     - 'adjust_rectangle_recency'
#     - 'auto_like_recency'
#     - 'bottom_nav_tap_shortterm_count'
#     - 'buy_check_buy_tap_longterm_count'
#     - 'buy_check_payment_tap_recency'
#     - 'buy_check_shipping_tap_recency'
#     - 'buy_complete_longterm_count'
#     - 'buy_coupon_apply_display_recency'
#     - 'buy_coupon_apply_tap_recency'
#     - 'buy_coupon_select_recency'
#     - 'buy_docomo_connect_display_longterm_count'
#     - 'buy_docomo_connect_display_recency'
#     - 'buy_purchase_display_longterm_count'
#     - 'buy_recency'
#     - 'codepay_code_display_recency'
#     - 'codepay_pay_confirm_display_recency'
#     - 'comments_recency'
#     - 'coupon_detail_tap_recency'
#     - 'coupon_display_longterm_count'
#     - 'coupon_display_recency'
#     - 'cpn_view_202107_buyCPN_recency'
#     - 'dashboard_code_success_display_recency'
#     - 'dashboard_point_history_display_recency'
#     - 'dashboard_point_history_period_tab_tap_recency'
#     - 'dashboard_point_history_record_tap_recency'
#     - 'dashboard_wallet_btn_tap_recency'
#     - 'display_mercari_books_entrance_longterm_count'
#     - 'easypay_lp_display_recency'
#     - 'entry_202109listingcpn_recency'
#     - 'followee_tap_longterm_count'
#     - 'halloween_recency'
#     - 'home_banner_tap_longterm_count'
#     - 'home_banner_tap_recency'
#     - 'home_component_item_imp_recency'
#     - 'home_component_item_tap_shortterm_count'
#     - 'home_screen_refresh_longterm_count'
#     - 'home_scroll_recency'
#     - 'home_scroll_shortterm_count'
#     - 'home_search_bar_tap_shortterm_count'
#     - 'ic_chip_kyc_back_tap_close_recency'
#     - 'inventory_list_item_tap_longterm_count'
#     - 'item_badge_view_shortterm_count'
#     - 'item_buyerprotection_tap_recency'
#     - 'item_comment_send_recency'
#     - 'item_detail_smart_payment_area_display_shortterm_count'
#     - 'item_detail_smart_payment_button_tap_recency'
#     - 'item_like_tap_longterm_count'
#     -  'item_like_tap_shortterm_count'
#     - 'item_photo_zoom_recency'
#     - 'item_seller_information_recency'
#     - 'jp_d_202109_87912_50_view_recency'
#     - 'likes_recency'
#     - 'likes_views_likes_tap_recency'
#     - 'likes_views_likes_tap_shortterm_count'
#     - 'likes_views_views_tap_recency'
#     -  'long_term_buy_count'
#     - 'long_term_buy_price_sum'
#     - 'long_term_comment_count'
#     - 'long_term_like_count'
#     - 'long_term_outer_pay_count'
#     - 'long_term_outer_pay_value_sum'
#     - 'menu_coupon_tap_new_recency'
#     - 'menu_point_tap_new_recency'
#     - 'merpay_coupon_code_display_longterm_count'
#     - 'merpay_coupon_code_payment_tap_longterm_count'
#     - 'merpay_coupon_detail_display_longterm_count'
#     - 'merpay_coupon_list_display_view_recency'
#     - 'merpay_coupon_list_tap_recency'
#     - 'merpay_coupon_list_top_display_recency'
#     - 'mypage_pointback_popup_display_longterm_count'
#     - 'mypage_pointback_popup_display_recency'
#     - 'mypage_postpay_detail_tap_recency'
#     - 'np_carousel_display_recency'
#     - 'register_recency'
#     - 'review_list_display_recency'
#     - 'saved_search_condition_deletion_select_recency'
#     - 'saved_search_condition_display_recency'
#     - 'saved_search_condition_new_setting_page_display_recency'
#     - 'saved_search_item_tap_longterm_count'
#     - 'search_execute_shortterm_count'
#     - 'search_filter_option_complete_recency'
#     - 'sell_catalog_suggest_button_show_recency'
#     - 'shopscpn_202108_ev_recency'
#     - 'short_term_buy_count'
#     - 'short_term_buy_price_sum'
#     - 'short_term_comment_count'
#     - 'short_term_like_count'
#     - 'short_term_outer_pay_count'
#     - 'short_term_outer_pay_value_sum'
#     - 'similar_item_component_item_tap_recency'
#     - 'similar_on_item_tap_recency'
#     - 'sorting_tab_display_recency'
#     - 'subliminal_component_display_ghost_longterm_count'
#     - 'swipe_back_shortterm_count'
#     - 'view_202109listingcpn_recency'
#
# ==============================================
# [DataService 2022-12-30 22:11:18] INFO Setup [DataService]
# [DataService 2022-12-30 22:11:18] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] start [0.2GB(49.8%)]
# [DataService 2022-12-30 22:11:21] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] done [2.4GB(54.3%)(+2.185GB)] 2.9457 s
# [DataService 2022-12-30 22:11:21] INFO df.shape: (660000, 102)
# [PreprocessService 2022-12-30 22:11:21] INFO Setup [PreprocessService]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] start [2.8GB(55.2%)]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] done [2.8GB(54.8%)(-0.042GB)] 0.0725 s

# %%
from sklearn.mixture import GaussianMixture
import scipy

# %%
import cvxpy as cp
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from src.services.base.base_service import BaseService
from src.utils import save_as_pickle

class ClusterWithUncertaintyPostprocess(BaseService):
    def __init__(self, base_config, postprocess_config):
        super().__init__()
        self.base_config = base_config
        self.postprocess_config = postprocess_config
        self.cost = np.array(
            list(self.postprocess_config.variant_no_to_cost.values())[1:]
        )
        self.n_cluster = self.postprocess_config.params["n_cluster"]

    def postprocess(self, uplift_mat, budget_constraint: float, seed: int):
        # clustering
        self.n_treatment = uplift_mat.shape[1]
        clustering_model = self.get_clustering()
        clustering_model.fit(uplift_mat)
        save_clustering_model_path = (
            self.base_config.dir_config.output_model_dir
            / f"clustering_model_{seed}_{budget_constraint}.pkl"
        )
        save_as_pickle(clustering_model, save_clustering_model_path)

        # # get cluster labels
        labels = clustering_model.predict(uplift_mat)
        np.save(
            self.base_config.dir_config.output_optimize_dir
            / f"cluster_{seed}_{budget_constraint}.npy",
            labels,
        )

        uplift_df = pd.DataFrame(uplift_mat)
        pi_bar = uplift_df.groupby(labels).mean().sort_index().values.flatten()
        cov_mat = self.get_cov_mat(uplift_df, labels)
        
        # optimize
        x = self.optimize(
            pi_bar, cov_mat, labels, budget_constraint
        )  # x.shape = (n_cluster, n_treatment)

        # sampling each cluster
        assign_df = pd.DataFrame(index=uplift_df.index, columns=['assign'])
        assign_df['assign'] = 0
        assign_df['cluster'] = labels

        for cluster in range(self.n_cluster):
            for coupon in range(self.n_treatment):
                _assign_df = assign_df.query(f'cluster == {cluster} and assign == 0')
                n_assign = min(
                    math.floor(x[cluster, coupon]),
                    _assign_df.shape[0]
                )
                if n_assign > 0:
                    _sample_idx = _assign_df.sample(n_assign, random_state=0).index
                    assign_df.loc[_sample_idx, 'assign'] = coupon + 1

        return assign_df["assign"].to_numpy()

    def get_clustering(self):
        if self.postprocess_config.params["clustering"] == "kmeans":
            return KMeans(
                n_clusters=self.n_cluster,
                random_state=self.base_config.seed,
            )
        elif self.postprocess_config.params["clustering"] == "gmm":
            return GaussianMixture(
                n_components=self.n_cluster,
                random_state=self.base_config.seed,
            )

    def get_cov_mat(self, uplift_df: pd.DataFrame, labels):
        bootstrap_samples = []
        B = 1000
        for i in tqdm(range(B)):
            sample_idx = np.random.choice(len(uplift_df), len(uplift_df), replace=True)
            sample_uplift_pred = uplift_df.iloc[sample_idx]
            sample_uplift_pred = sample_uplift_pred.groupby(labels).mean().sort_index().values.flatten()
            bootstrap_samples.append(sample_uplift_pred)
        bootstrap_samples = np.stack(bootstrap_samples)
        cov_mat = np.cov(bootstrap_samples, rowvar=False, bias=False)

        return cov_mat

    def optimize(self, pi_bar, cov_mat, labels, budget_constraint):
        gamma = cp.Variable(shape=(self.n_cluster*self.n_treatment, 1), nonneg=True)
        cov_mat = cp.atoms.affine.wraps.psd_wrap(cov_mat)

        # Objective (Return & Risk)
        ret = pi_bar @ gamma
        risk = cp.quad_form(gamma, cov_mat)
        lam = self.postprocess_config.params["lambda"]
        objective = cp.Maximize((1-lam)*ret - lam*risk)

        # Constraints
        constraints = []

        ## Budget Constraint
        costs = np.tile(self.cost, self.n_cluster)
        constraints.append(costs @ gamma <= budget_constraint)

        ## Cluster size Constraint
        cluster_sizes = np.unique(labels, return_counts=True)[1]
        for i in range(cluster_sizes.shape[0]):
            size = cluster_sizes[i]
            _gamma = gamma[i*self.n_treatment:(i+1)*self.n_treatment]
            constraints.append(cp.sum(_gamma) <= size)

        # solve
        prob = cp.Problem(objective, constraints)
        prob.solve(solver=cp.SCS, verbose=True)

        return gamma.value.reshape(self.n_cluster, self.n_treatment)

# %%
len(uplift_pred) * 16 * 0.2, len(uplift_pred) * 16
# Out:
# (422400.0, 2112000)

# %%
400000 * 5 - 400000
# Out:
# 1600000

# %%
np.linspace(400000, 400000 * 5, 5)
# Out:
# array([ 400000.,  800000., 1200000., 1600000., 2000000.])

# %%
import cvxpy as cp

# %%
n_cluster = 10
n_treatment = uplift_pred.shape[1]
lam = 0.1

gamma = cp.Variable(shape=(n_cluster*n_treatment, 1), nonneg=True)
pi_bar = uplift_pred.groupby(pred_cluster).mean().sort_index().values.flatten()
cov_mat = np.cov(bootstrap_samples, rowvar=False, bias=False)
cov_mat = cp.atoms.affine.wraps.psd_wrap(cov_mat)

ret = pi_bar @ gamma
risk = cp.quad_form(gamma, cov_mat)

objective = cp.Maximize((1-lam)*ret - lam*risk)
constraints = []

# budget constraint
budget_constraint = 100000000000
coupon_cost = np.array([5, 5, 13, 10, 10, 15])
costs = np.tile(coupon_cost, n_cluster)
constraints.append(costs @ gamma <= budget_constraint)

# cluster size constraint
cluster_sizes = np.unique(pred_cluster, return_counts=True)[1]
for i in range(cluster_sizes.shape[0]):
    size = cluster_sizes[i]
    _gamma = gamma[i*n_treatment:(i+1)*n_treatment]
    constraints.append(cp.sum(_gamma) <= size)

# solve
prob = cp.Problem(objective, constraints)
prob.solve(solver=cp.SCS, verbose=True)

x = gamma.value.reshape(n_cluster, n_treatment)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.2
# ===============================================================================
# (CVXPY) Dec 31 12:07:13 AM: Your problem has 60 variables, 11 constraints, and 0 parameters.
# (CVXPY) Dec 31 12:07:13 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Dec 31 12:07:13 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Dec 31 12:07:13 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Dec 31 12:07:13 AM: Compiling problem (target solver=SCS).
# (CVXPY) Dec 31 12:07:13 AM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Dec 31 12:07:13 AM: Applying reduction FlipObjective
# (CVXPY) Dec 31 12:07:13 AM: Applying reduction Dcp2Cone
# (CVXPY) Dec 31 12:07:13 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Dec 31 12:07:13 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Dec 31 12:07:13 AM: Applying reduction SCS
# (CVXPY) Dec 31 12:07:13 AM: Finished problem compilation (took 4.984e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Dec 31 12:07:13 AM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 61, constraints m: 133
# cones: 	  l: linear vars: 71
# 	  q: soc vars: 62, qsize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 3782, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1
| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.18e+00
#  88250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.19e+00
#  88500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.19e+00
#  88750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.19e+00
#  89000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.20e+00
#  89250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.20e+00
#  89500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.20e+00
#  89750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.21e+00
#  90000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.21e+00
#  90250| 2.75e+03  4.51e-03  3.00e+07 -2.61e+07  1.00e-06  1.21e+00
#  90500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.22e+00
#  90750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.22e+00
#  91000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.22e+00
#  91250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.23e+00
#  91500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.23e+00
#  91750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.23e+00
#  92000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.24e+00
#  92250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.24e+00
#  92500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.24e+00
#  92750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.25e+00
#  93000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.25e+00
#  93250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.25e+00
#  93500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.26e+00
#  93750| 2.75e+03  4.51e-03  3.00e+07 -2.61e+07  1.00e-06  1.26e+00
#  94000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.26e+00
#  94250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.27e+00
#  94500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.27e+00
#  94750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.27e+00
#  95000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.28e+00
#  95250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.28e+00
#  95500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.28e+00
#  95750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.29e+00
#  96000| 2.75e+03  4.51e-03  3.00e+07 -2.61e+07  1.00e-06  1.29e+00
#  96250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.29e+00
#  96500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.30e+00
#  96750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.30e+00
#  97000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.30e+00
#  97250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.31e+00
#  97500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.31e+00
#  97750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.31e+00
#  98000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.32e+00
#  98250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.32e+00
#  98500| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.32e+00
#  98750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.33e+00
#  99000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.33e+00
#  99250| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.33e+00
#  99500| 2.75e+03  4.51e-03  3.00e+07 -2.61e+07  1.00e-06  1.34e+00
#  99750| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.34e+00
# 100000| 2.75e+03  4.50e-03  3.00e+07 -2.61e+07  1.00e-06  1.34e+00
# ------------------------------------------------------------------
# status:  solved (inaccurate - reached max_iters)
# timings: total: 1.34e+00s = setup: 1.33e-03s + solve: 1.34e+00s
# 	 lin-sys: 1.24e+00s, cones: 1.45e-02s, accel: 1.27e-02s
# ------------------------------------------------------------------
# objective = -26125102.492926 (inaccurate)
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Dec 31 12:07:14 AM: Problem status: optimal_inaccurate
# (CVXPY) Dec 31 12:07:14 AM: Optimal value: -1.698e+09
# (CVXPY) Dec 31 12:07:14 AM: Compilation took 4.984e-02 seconds
# (CVXPY) Dec 31 12:07:14 AM: Solver (including time spent in interface) took 1.344e+00 seconds
# /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/.venv/lib/python3.8/site-packages/cvxpy/problems/problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
assign_df = pd.DataFrame(index=uplift_pred.index, columns=['assign'])
assign_df['assign'] = 0
assign_df['cluster'] = pred_cluster

for cluster in range(n_cluster):
    for coupon in range(n_treatment):
        _assign_df = assign_df.query(f'cluster == {cluster} and assign == 0')
        n_assign = min(
            math.floor(x[cluster, coupon]),
            _assign_df.shape[0]
        )
        if n_assign > 0:
            _sample_idx = _assign_df.sample(n_assign, random_state=0).index
            assign_df.loc[_sample_idx, 'assign'] = coupon + 1

# %%
x.sum(axis=0)
# Out:
# array([ 3265.37275005,  3429.3673902 , 81546.66233254,  1300.70148678,
#        37134.46084405,   606.13345687])

# %%
assign_df['assign'].value_counts().sort_index()
# Out:
# 0     5531
# 1     3111
# 2     2968
# 3    81500
# 4     1232
# 5    37087
# 6      571
# Name: assign, dtype: int64
