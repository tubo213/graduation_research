# %%
from src.containers.evaluation_container import EvaluationContainer
from src.services.config.config_interface import DirConfig
from src.utils import tqdm_joblib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from joblib import Parallel, delayed
import multiprocessing
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import japanize_matplotlib

plt.style.use("ggplot")
dir_config = DirConfig(env='local', exp='eval_previous', debug=False)

coupon_type_to_color = {
    'control': '#E24A33',
    '5% back': '#348ABD',
    '5% off':'#988ED5',
    '300yen off':'#777777',  
    '10% off': '#FBC15E', 
    '10% back': '#8EBA42', 
    '15% off': '#FFB5B8'
}

# %% [markdown]
# # 一番良かったExp

# %%
## 一番良かったExp
def plot_allocation(container):
    clusters = container.clusters
    assignments = container.assignments
    n_budget = len(clusters)

    # sort by budget
    cluster = sorted(clusters, key=lambda x: x[1])[0][-1]
    assignments = sorted(assignments, key=lambda x: x[1])

    # plot
    fig, axes = plt.subplots(n_budget, 1, figsize=(20, 5 * n_budget))
    for i, (assignment) in enumerate(assignments):
        budget_constraint = assignment[1]
        assignment = assignment[-1]

        df = pd.DataFrame({'cluster': cluster, 'assignment': assignment})
        df = df.sort_values('assignment', ascending=False)
        df = df.groupby(['cluster', 'assignment']).size().reset_index().sort_values('assignment')
        df = df.pivot(index='cluster', columns='assignment', values=0).fillna(0)
        df.columns = list(map(lambda x: container.config.base_config.counpon_config.variant_no_to_coupon_type[x], df.columns))
        (
            df.plot.bar(
                stacked=True, 
                ax=axes[i], 
                legend=True, 
                title=f'budget constraint={budget_constraint:.0f}',
                color=coupon_type_to_color
            )
        )
        axes[i].set_ylabel('クラスターサイズ', fontsize=25)
        axes[i].set_xlabel('クラスター番号', fontsize=25)
    
    fig.tight_layout()

    return fig, axes

def plot_cluster(container):
    cluster = container.clusters[0][-1]
    uplift = container.uplift_pred
    columns = list(container.config.base_config.counpon_config.variant_no_to_coupon_type.values())[1:]
    uplift.columns = columns

    fig, axes = plt.subplots(2, 1, figsize=(20, 5*2), sharey=False, sharex=False)
    # mean uplift
    uplift.groupby(cluster).sum().plot.bar(stacked=True, 
                                           ax=axes[0], 
                                           color=coupon_type_to_color
                                           )
    # std uplift
    uplift.groupby(cluster).std().plot.bar(stacked=True, ax=axes[1], color=coupon_type_to_color)

    axes[0].set_ylabel('総Uplift', fontsize=25)
    axes[1].set_ylabel('標準偏差', fontsize=25)
    axes[0].set_xlabel('クラスター番号', fontsize=25)
    axes[1].set_xlabel('クラスター番号', fontsize=25)
    fig.tight_layout()

    return fig, axes

# %%
container = EvaluationContainer('optimize208', debug=False)
container.initialize()
# Out:
# [EvaluationContainer 2022-12-31 15:07:48] INFO Setup [EvaluationContainer]
# [ConfigService 2022-12-31 15:07:48] INFO Setup [ConfigService]
# [ConfigService 2022-12-31 15:07:48] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-12-31 15:07:48] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/outputs')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/predictions')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/models')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/figures')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize')}
# [ConfigService 2022-12-31 15:07:48] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize208.yaml
# =============== /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize208.yaml =================
# coupon_config:
#   variant_no_to_coupon_type:
#     0: control
#     1: 5% back
#     2: 5% off
#     3: 300yen off
#     4: 10% off
#     5: 10% back
#     6: 15% off
# name: s-learner, previous_research, lambda=0, cluster=50
# postprocess_config:
#   n_sample: 9999999
#   n_seed: 1
#   name: cluster_with_uncertainty
#   params:
#     alpha: 0
#     clustering: gmm
#     lambda: 0
#     n_cluster: 50
#   variant_no_to_cost:
#     0: 0
#     1: 5
#     2: 5
#     3: 13
#     4: 10
#     5: 10
#     6: 15
# problem_type: regression
# seed: 77
# target_name: gmv_28day
# train_name: train001
# treatment_name: treatment
#
# ==============================================
# [ConfigService 2022-12-31 15:07:48] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-12-31 15:07:48] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/outputs')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/models')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/figures')}
# [ConfigService 2022-12-31 15:07:48] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/optimize')}
# [ConfigService 2022-12-31 15:07:48] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train001.yaml
# [DataService 2022-12-31 15:07:48] INFO Setup [DataService]
# [DataService 2022-12-31 15:07:48] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] start [0.3GB(39.2%)]
# [DataService 2022-12-31 15:07:52] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] done [2.6GB(38.5%)(+2.327GB)] 3.0731 s
# [DataService 2022-12-31 15:07:52] INFO df.shape: (660000, 102)
# [PreprocessService 2022-12-31 15:07:52] INFO Setup [PreprocessService]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] start [3.0GB(39.4%)]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] done [2.9GB(39.1%)(-0.042GB)] 0.0720 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_2000000.0_0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_2000000.0_0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0012 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_1600000.0_0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_1600000.0_0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0012 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_1200000.0_0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_1200000.0_0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0009 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_800000.0_0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_800000.0_0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0010 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_400000.0_0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/assignment_400000.0_0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_400000.0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_400000.0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0009 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_1600000.0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_1600000.0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_1200000.0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_1200000.0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_800000.0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_800000.0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_2000000.0.npy] start [2.9GB(39.1%)]
# [EvaluationContainer 2022-12-31 15:07:52] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize208/optimize/cluster_0_2000000.0.npy] done [2.9GB(39.1%)(+0.000GB)] 0.0007 s

# %%
fig, axes = plot_cluster(container)
fig.savefig(dir_config.output_figure_dir / 'cluster.png')

# %%
fig, axes = plot_allocation(container)
fig.savefig(dir_config.output_figure_dir / 'allocation.png')

# %% [markdown]
# # ハイパーパラメータ毎の精度変化

# %%
def evaluate(exp):
    container = EvaluationContainer(exp, debug=False)
    name = container.config.base_config.name
    container.initialize()
    base_config = container.config.base_config
    config = container.config
    postprocess_config = config.postprocess_config

    n_sample = min(container.test_df.shape[0], postprocess_config.n_sample)
    random_checked = set()
    results =[]
    # self.assignments.append([name, seed, budget_constraint, assignment])
    for seed, budget_constraint, assginment in container.assignments:
        # test_dfからランダムにn_sample個のidxを取得
        sample_idx = container.test_df.sample(n_sample, random_state=seed).index.to_numpy()
        # sample_idxのデータを取得しsample_dfに格納
        sample_df = container.test_df.loc[sample_idx].copy().reset_index(drop=True)
        # target列にGMVを代入
        sample_df['target'] = sample_df[base_config.target_name]
        # sample_dfのなかで各config.treatment_nameの数をカウント
        n_treatment = sample_df[base_config.treatment_name].value_counts().to_dict()
        n_treatment_all = sum(n_treatment.values())
        # cost列にvariant_no_to_costの値を代入
        sample_df['cost'] = sample_df[base_config.treatment_name].map(postprocess_config.variant_no_to_cost)
            
        # model
        gmv = 0
        cost = 0
        for t in range(1, 7):
            gmv += sample_df['target'][(assginment==t) & (sample_df[base_config.treatment_name]==t)].sum()*(n_treatment_all/n_treatment[t])
            gmv -= sample_df['target'][(assginment==t) & (sample_df[base_config.treatment_name]!=t)].sum()*(n_treatment_all/(1-n_treatment[t]))
            cost += sample_df['cost'][(assginment==t) & (sample_df[base_config.treatment_name]==t)].sum()
            # cost -= sample_df['cost'][(assginment==t) & (sample_df[config.treatment_name]!=t)].sum()*(n_treatment_all/(1-n_treatment[t]))
        rate = (sample_df['target'][(assginment==sample_df[base_config.treatment_name])]!=0).mean()
        results.append([exp, name, seed, cost, gmv, rate, budget_constraint])
    return results


def split_name(name):
    return (
        name.str.split(',', expand=True)
        .iloc[:, 2:]
        .applymap(lambda x: x.split('=')[-1] if isinstance(x, str) else None)
        .astype(float)
    )

# %%
results = []
exps = [f'optimize{i:03}' for i in range(206, 234)]
num_cores = multiprocessing.cpu_count()
with tqdm_joblib(len(exps)):
    results = Parallel(n_jobs=num_cores)([delayed(evaluate)(exp) for exp in exps])

# flatten
results = [item for sublist in results for item in sublist]

result_df = pd.DataFrame(results, columns=['exp', 'name', 'seed', 'cost', 'GMV', 'assign_rate', 'budget_constraint'])
result_df['cost'] = result_df['cost'].astype(int)
result_df = result_df.drop_duplicates().reset_index(drop=True)
result_df['random'] = result_df['name'] == 'random'
result_df = result_df.sort_values(['random', 'name','cost','seed'])
result_df['sum_GMV'] = result_df.groupby('name')['GMV'].transform('sum')

# %%
result_df[['lam', 'cluster']] = split_name(result_df['name'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 5))

for name in result_df.groupby('name')['GMV'].sum().sort_values(ascending=False).index[:10]:
    _result_df = result_df[result_df['name'] == name]
    # lam = float(name.split(',')[-1].split('=')[-1])
    lam = _result_df['lam'].values[0]
    cluster = _result_df['cluster'].values[0]

    x = _result_df['cost'].values
    y = _result_df['GMV'].values
    label = f'lambda={lam}, cluster={cluster}'
    ax.plot(x, y, label=name, marker='o', markersize=5, linewidth=2)
    ax.legend()

ax.legend()

# %%
agg_df = result_df.groupby('name')['GMV'].sum().sort_values(ascending=False).reset_index()
agg_df[['lambda', 'cluster']] = split_name(agg_df['name'])
agg_df = agg_df.dropna().reset_index(drop=True)

# %%
sns.swarmplot(x='lambda', y='GMV', hue='cluster', data=agg_df, palette='Blues')
# Out:
# <AxesSubplot: xlabel='lambda', ylabel='GMV'>

# %%
sns.swarmplot(x='cluster', y='GMV', hue='lambda', data=agg_df, palette='Blues')
# Out:
# <AxesSubplot: xlabel='cluster', ylabel='GMV'>

# %%
heatmap = pd.pivot_table(agg_df, index='lambda', columns='cluster', values='GMV', aggfunc='sum')
sns.heatmap(heatmap, annot=True, cmap='Blues')
# Out:
# <AxesSubplot: xlabel='cluster', ylabel='lambda'>
