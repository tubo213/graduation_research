# %%
from src.containers.evaluation_container import EvaluationContainer
from src.services.config.config_interface import DirConfig

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
eval_dir_config = DirConfig('local', 'eval001', False)

# %%
results = []
for exp in [
    'optimize001', 'optimize002', 
    'optimize003', 'optimize004', 
    'optimize005', 'optimize006', 
    'optimize007', 'optimize008'
    ]:
    container = EvaluationContainer(exp, debug=False)
    name = container.config.base_config.name
    container.initialize()
    base_config = container.config.base_config
    config = container.config
    postprocess_config = config.postprocess_config

    n_sample = min(container.test_df.shape[0], postprocess_config.n_sample)
    random_checked = set()
    # self.assignments.append([name, seed, budget_constraint, assignment])
    for seed, budget_constraint, assginment in container.assignments:
        # test_dfからランダムにn_sample個のidxを取得
        sample_idx = container.test_df.sample(n_sample, random_state=seed).index.to_numpy()
        # sample_idxのデータを取得しsample_dfに格納
        sample_df = container.test_df.loc[sample_idx].copy().reset_index(drop=True)
        # target列にGMVを代入
        sample_df['target'] = sample_df[base_config.target_name]
        # sample_dfのなかで各config.treatment_nameの数をカウント
        n_treatment = sample_df[base_config.treatment_name].value_counts().to_dict()
        n_treatment_all = sum(n_treatment.values())
        # cost列にvariant_no_to_costの値を代入
        sample_df['cost'] = sample_df[base_config.treatment_name].map(postprocess_config.variant_no_to_cost)
        # random
        if (seed,budget_constraint) not in random_checked:
            # cost列の累積和がbudget_constraintを超えるidxを取得 frac=1は100%とってきてシャッフル
            # assign_indexはあとで0にするindex
            assgin_index = (sample_df.sample(frac=1)['cost'].cumsum() > budget_constraint).sort_index()
            # assginment列に0~6の乱数を代入 -> 1~6では？ 
            sample_df['assginment'] = np.random.randint(0, 7, len(sample_df))
            # assgin_indexのidxに0を上書き
            sample_df.loc[assgin_index, 'assginment'] = 0
            # upliftgmv
            random_gmv = 0
            cost = 0
            for t in range(1, 7):
                random_gmv += sample_df['target'][(sample_df['assginment']==t) & (sample_df[base_config.treatment_name]==t)].sum()*(n_treatment_all/n_treatment[t])
                random_gmv -= sample_df['target'][(sample_df['assginment']==t) & (sample_df[base_config.treatment_name]!=t)].sum()*(n_treatment_all/(1-n_treatment[t]))
                cost += sample_df['cost'][(sample_df['assginment']==t)& (sample_df[base_config.treatment_name]==t)].sum()
                #cost -= sample_df['cost'][(sample_df['assginment']==t) & (sample_df[config.treatment_name]!=t)].sum()*(n_treatment_all/(1-n_treatment[t]))
            # 一致しているものの割合 -> つかってない
            # 実際のconfig.treatment_nameとassginmentが一致していないものを集計
            random_rate = (sample_df['target'][(assginment==sample_df[base_config.treatment_name])]!=0).mean()
            results.append(['random', seed, budget_constraint, random_gmv, random_rate])   
            random_checked.add((seed,budget_constraint))
            
        # model
        gmv = 0
        cost = 0
        for t in range(1, 7):
            gmv += sample_df['target'][(assginment==t) & (sample_df[base_config.treatment_name]==t)].sum()*(n_treatment_all/n_treatment[t])
            gmv -= sample_df['target'][(assginment==t) & (sample_df[base_config.treatment_name]!=t)].sum()*(n_treatment_all/(1-n_treatment[t]))
            cost += sample_df['cost'][(assginment==t) & (sample_df[base_config.treatment_name]==t)].sum()
            # cost -= sample_df['cost'][(assginment==t) & (sample_df[config.treatment_name]!=t)].sum()*(n_treatment_all/(1-n_treatment[t]))
        rate = (sample_df['target'][(assginment==sample_df[base_config.treatment_name])]!=0).mean()
        results.append([name, seed, budget_constraint, gmv, rate])

result_df = pd.DataFrame(results, columns=['name', 'seed', 'budget_constraint', 'GMV', 'assign_rate'])
result_df['budget_constraint'] = result_df['budget_constraint'].astype(int)
result_df = result_df.drop_duplicates().reset_index(drop=True)
result_df['random'] = result_df['name'] == 'random'
result_df = result_df.sort_values(['random', 'name','budget_constraint','seed'])
result_df[['metalearner', 'optimization']] = result_df['name'].str.split(', ', expand=True)
# Out:
# [EvaluationContainer 2022-11-28 10:28:48] INFO Setup [EvaluationContainer]
# [ConfigService 2022-11-28 10:28:48] INFO Setup [ConfigService]
# [ConfigService 2022-11-28 10:28:48] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:28:48] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/outputs')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/predictions')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/models')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/figures')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize')}
# [ConfigService 2022-11-28 10:28:48] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize001.yaml
# =============== /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize001.yaml =================
# name: "s-learner, robust"
# seed: 77
# problem_type: regression
# target_name: gmv_28day
# treatment_name: treatment
# coupon_config:
#   variant_no_to_coupon_type:
#     0: "control"
#     1: "5% back"
#     2: "5% off"
#     3: "300yen off"
#     4: "10% off"
#     5: "10% back"
#     6: "15% off"
# train_name: train001
#
# postprocess_config:
#   name: 'robust'
#   params:
#     clustering: 'gmm'
#     n_cluster: 10
#     gamma: 30
#   n_sample: 9999999
#   n_seed: 1
#   variant_no_to_cost:
#     0: 0
#     1: 5
#     2: 5
#     3: 13
#     4: 10
#     5: 10
#     6: 15
#
# ==============================================
# [ConfigService 2022-11-28 10:28:48] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:28:48] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/outputs')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/models')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/figures')}
# [ConfigService 2022-11-28 10:28:48] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/optimize')}
# [ConfigService 2022-11-28 10:28:48] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train001.yaml
# [DataService 2022-11-28 10:28:48] INFO Setup [DataService]
# [DataService 2022-11-28 10:28:48] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] start [3.5GB(34.0%)]
# [DataService 2022-11-28 10:28:51] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] done [3.7GB(34.3%)(+0.137GB)] 2.6534 s
# [DataService 2022-11-28 10:28:51] INFO df.shape: (660000, 102)
# [PreprocessService 2022-11-28 10:28:51] INFO Setup [PreprocessService]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] start [3.7GB(34.3%)]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] done [3.6GB(34.2%)(-0.025GB)] 0.0624 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_396000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_396000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1980000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1980000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1804000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1804000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_572000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_572000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1100000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1100000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_748000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_748000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1276000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1276000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1628000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1628000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_924000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_924000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1452000.0_0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/assignment_1452000.0_0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1452000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1452000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1628000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1628000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1804000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1804000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_924000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_924000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1100000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1100000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_572000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_572000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1276000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1276000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_396000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_396000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1980000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_1980000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_748000.0.npy] start [3.6GB(34.2%)]
# [EvaluationContainer 2022-11-28 10:28:51] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize001/optimize/cluster_0_748000.0.npy] done [3.6GB(34.2%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:53] INFO Setup [EvaluationContainer]
# [ConfigService 2022-11-28 10:28:53] INFO Setup [ConfigService]
# [ConfigService 2022-11-28 10:28:53] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:28:53] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/outputs')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/predictions')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/models')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/figures')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize')}
# [ConfigService 2022-11-28 10:28:53] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize002.yaml
# =============== /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize002.yaml =================
# name: "s-learner, cluster"
# seed: 77
# problem_type: regression
# target_name: gmv_28day
# treatment_name: treatment
# coupon_config:
#   variant_no_to_coupon_type:
#     0: "control"
#     1: "5% back"
#     2: "5% off"
#     3: "300yen off"
#     4: "10% off"
#     5: "10% back"
#     6: "15% off"
# train_name: train001
#
# postprocess_config:
#   name: 'cluster'
#   params:
#     clustering: 'gmm'
#     n_cluster: 10
#     gamma: 30
#   n_sample: 9999999
#   n_seed: 1
#   variant_no_to_cost:
#     0: 0
#     1: 5
#     2: 5
#     3: 13
#     4: 10
#     5: 10
#     6: 15
#
# ==============================================
# [ConfigService 2022-11-28 10:28:53] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:28:53] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/outputs')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/models')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/figures')}
# [ConfigService 2022-11-28 10:28:53] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/optimize')}
# [ConfigService 2022-11-28 10:28:53] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train001.yaml
# [DataService 2022-11-28 10:28:53] INFO Setup [DataService]
# [DataService 2022-11-28 10:28:53] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] start [3.7GB(34.2%)]
# [DataService 2022-11-28 10:28:56] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] done [3.8GB(34.5%)(+0.167GB)] 2.7665 s
# [DataService 2022-11-28 10:28:56] INFO df.shape: (660000, 102)
# [PreprocessService 2022-11-28 10:28:56] INFO Setup [PreprocessService]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] start [3.8GB(34.5%)]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train001/predictions/uplift_pred.csv] done [3.8GB(34.5%)(-0.019GB)] 0.0653 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_396000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_396000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1980000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1980000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1804000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1804000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_572000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_572000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1100000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1100000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_748000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_748000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1276000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1276000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1628000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1628000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_924000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_924000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1452000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/assignment_1452000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1452000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1452000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1628000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1628000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1804000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1804000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_924000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_924000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1100000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1100000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_572000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_572000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1276000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1276000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_396000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_396000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1980000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_1980000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_748000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:28:56] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize002/optimize/cluster_0_748000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:28:57] INFO Setup [EvaluationContainer]
# [ConfigService 2022-11-28 10:28:57] INFO Setup [ConfigService]
# [ConfigService 2022-11-28 10:28:57] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:28:57] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/outputs')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/predictions')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/models')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/figures')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize')}
# [ConfigService 2022-11-28 10:28:57] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize003.yaml
# =============== /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize003.yaml =================
# name: "t-learner, robust"
# seed: 77
# problem_type: regression
# target_name: gmv_28day
# treatment_name: treatment
# coupon_config:
#   variant_no_to_coupon_type:
#     0: "control"
#     1: "5% back"
#     2: "5% off"
#     3: "300yen off"
#     4: "10% off"
#     5: "10% back"
#     6: "15% off"
# train_name: train002
#
# postprocess_config:
#   name: 'robust'
#   params:
#     clustering: 'gmm'
#     n_cluster: 10
#     gamma: 30
#   n_sample: 9999999
#   n_seed: 1
#   variant_no_to_cost:
#     0: 0
#     1: 5
#     2: 5
#     3: 13
#     4: 10
#     5: 10
#     6: 15
#
# ==============================================
# [ConfigService 2022-11-28 10:28:57] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:28:57] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/outputs')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/predictions')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/models')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/figures')}
# [ConfigService 2022-11-28 10:28:57] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/optimize')}
# [ConfigService 2022-11-28 10:28:57] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train002.yaml
# [DataService 2022-11-28 10:28:57] INFO Setup [DataService]
# [DataService 2022-11-28 10:28:57] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] start [3.8GB(34.5%)]
# [DataService 2022-11-28 10:29:00] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] done [3.8GB(34.5%)(+0.008GB)] 2.6528 s
# [DataService 2022-11-28 10:29:00] INFO df.shape: (660000, 102)
# [PreprocessService 2022-11-28 10:29:00] INFO Setup [PreprocessService]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/predictions/uplift_pred.csv] start [3.8GB(34.6%)]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/predictions/uplift_pred.csv] done [3.8GB(34.5%)(-0.029GB)] 0.0685 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_396000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_396000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1980000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1980000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1804000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1804000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_572000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_572000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1100000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1100000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_748000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_748000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1276000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1276000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1628000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1628000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_924000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_924000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1452000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/assignment_1452000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1452000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1452000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1628000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1628000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1804000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1804000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_924000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_924000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1100000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1100000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_572000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_572000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1276000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1276000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_396000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_396000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1980000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_1980000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_748000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:00] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize003/optimize/cluster_0_748000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:02] INFO Setup [EvaluationContainer]
# [ConfigService 2022-11-28 10:29:02] INFO Setup [ConfigService]
# [ConfigService 2022-11-28 10:29:02] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:29:02] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/outputs')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/predictions')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/models')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/figures')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize')}
# [ConfigService 2022-11-28 10:29:02] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize004.yaml
# =============== /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize004.yaml =================
# name: "t-learner, cluster"
# seed: 77
# problem_type: regression
# target_name: gmv_28day
# treatment_name: treatment
# coupon_config:
#   variant_no_to_coupon_type:
#     0: "control"
#     1: "5% back"
#     2: "5% off"
#     3: "300yen off"
#     4: "10% off"
#     5: "10% back"
#     6: "15% off"
# train_name: train002
#
# postprocess_config:
#   name: 'cluster'
#   params:
#     clustering: 'gmm'
#     n_cluster: 10
#     gamma: 30
#   n_sample: 9999999
#   n_seed: 1
#   variant_no_to_cost:
#     0: 0
#     1: 5
#     2: 5
#     3: 13
#     4: 10
#     5: 10
#     6: 15
#
# ==============================================
# [ConfigService 2022-11-28 10:29:02] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:29:02] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/outputs')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/predictions')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/models')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/figures')}
# [ConfigService 2022-11-28 10:29:02] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/optimize')}
# [ConfigService 2022-11-28 10:29:02] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train002.yaml
# [DataService 2022-11-28 10:29:02] INFO Setup [DataService]
# [DataService 2022-11-28 10:29:02] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] start [3.8GB(34.5%)]
# [DataService 2022-11-28 10:29:05] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] done [3.8GB(34.5%)(+0.026GB)] 2.6378 s
# [DataService 2022-11-28 10:29:05] INFO df.shape: (660000, 102)
# [PreprocessService 2022-11-28 10:29:05] INFO Setup [PreprocessService]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/predictions/uplift_pred.csv] start [3.8GB(34.6%)]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train002/predictions/uplift_pred.csv] done [3.8GB(34.5%)(-0.025GB)] 0.0677 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_396000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_396000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1980000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1980000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1804000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1804000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_572000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_572000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1100000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1100000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_748000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_748000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0020 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1276000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1276000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1628000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1628000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_924000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_924000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1452000.0_0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/assignment_1452000.0_0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/cluster_0_1452000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/cluster_0_1452000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/cluster_0_1628000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/cluster_0_1628000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/cluster_0_1804000.0.npy] start [3.8GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/cluster_0_1804000.0.npy] done [3.8GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:05] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize004/optimize/cluster_0_924000.0.npy] start [3.8GB(34.5%)]
# ...
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1804000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1804000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_924000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_924000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1100000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1100000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_572000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_572000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1276000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1276000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_396000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_396000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1980000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_1980000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_748000.0.npy] start [3.7GB(34.5%)]
# [EvaluationContainer 2022-11-28 10:29:18] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize007/optimize/cluster_0_748000.0.npy] done [3.7GB(34.5%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:20] INFO Setup [EvaluationContainer]
# [ConfigService 2022-11-28 10:29:20] INFO Setup [ConfigService]
# [ConfigService 2022-11-28 10:29:20] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:29:20] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/outputs')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/predictions')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/models')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/figures')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize')}
# [ConfigService 2022-11-28 10:29:20] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize008.yaml
# =============== /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/optimize008.yaml =================
# name: "transformedoutcome, cluster"
# seed: 77
# problem_type: regression
# target_name: gmv_28day
# treatment_name: treatment
# coupon_config:
#   variant_no_to_coupon_type:
#     0: "control"
#     1: "5% back"
#     2: "5% off"
#     3: "300yen off"
#     4: "10% off"
#     5: "10% back"
#     6: "15% off"
# train_name: train004
#
# postprocess_config:
#   name: 'cluster'
#   params:
#     clustering: 'gmm'
#     n_cluster: 10
#     gamma: 30
#   n_sample: 9999999
#   n_seed: 1
#   variant_no_to_cost:
#     0: 0
#     1: 5
#     2: 5
#     3: 13
#     4: 10
#     5: 10
#     6: 15
#
# ==============================================
# [ConfigService 2022-11-28 10:29:20] INFO {'root_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research')}
# [ConfigService 2022-11-28 10:29:20] INFO {'input_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_root': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004/outputs')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_prediction_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004/predictions')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_model_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004/models')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_figure_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004/figures')}
# [ConfigService 2022-11-28 10:29:20] INFO {'output_optimize_dir': PosixPath('/Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004/optimize')}
# [ConfigService 2022-11-28 10:29:20] INFO load yaml file: /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/yaml/train004.yaml
# [DataService 2022-11-28 10:29:20] INFO Setup [DataService]
# [DataService 2022-11-28 10:29:20] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] start [3.7GB(34.4%)]
# [DataService 2022-11-28 10:29:22] INFO [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/input/retention_campaign_users_and_features_202202.csv] done [3.7GB(34.4%)(+0.000GB)] 2.6700 s
# [DataService 2022-11-28 10:29:22] INFO df.shape: (660000, 102)
# [PreprocessService 2022-11-28 10:29:22] INFO Setup [PreprocessService]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004/predictions/uplift_pred.csv] start [3.7GB(34.4%)]
# [Read /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/train004/predictions/uplift_pred.csv] done [3.7GB(34.4%)(-0.019GB)] 0.0683 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_396000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_396000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1980000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1980000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1804000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1804000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_572000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_572000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1100000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1100000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_748000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_748000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1276000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1276000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1628000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1628000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_924000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_924000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1452000.0_0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/assignment_1452000.0_0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1452000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1452000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1628000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1628000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0005 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1804000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1804000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_924000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_924000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1100000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1100000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0006 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_572000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_572000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1276000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1276000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_396000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_396000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1980000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_1980000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0008 s
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_748000.0.npy] start [3.7GB(34.4%)]
# [EvaluationContainer 2022-11-28 10:29:23] INFO [Load /Users/tsukuba-yuuki-uehara/Desktop/projects/graduation_research/output/optimize008/optimize/cluster_0_748000.0.npy] done [3.7GB(34.4%)(+0.000GB)] 0.0007 s

# %%
fig, ax = plt.subplots(figsize=(20, 10), tight_layout=True)
linewidth = 5
markersize= 10

ax.plot(
    result_df.query('name == "random"')['budget_constraint'],
    result_df.query('name == "random"')['GMV'],
    label='random',
    color='black',
    linewidth=linewidth,
    markersize=markersize
)
sns.lineplot(data=result_df.query('optimization == "cluster"'), y='GMV', x='budget_constraint', hue='name',
             style='name',
             linewidth=linewidth,
             markersize=markersize,
             markers=True, 
             dashes=False,
             ax=ax)
sns.lineplot(data=result_df.query('optimization == "robust"'), y='GMV', x='budget_constraint', hue='name',
             style='name',
             linestyle='dashed',
             linewidth=linewidth,
             markersize=markersize,
             markers=True, 
             dashes=[(2, 2)] * len(result_df.query('optimization == "robust"')["name"].value_counts()),
             ax=ax)
ax.set_xlabel('budget_constraint', fontsize=40)
ax.set_ylabel('upliftGMV',fontsize=40)
ax.legend(fontsize=20)
ax.set_xticklabels(ax.get_xticks().astype(int), fontsize=20)
ax.set_yticklabels(ax.get_yticks().astype(int), fontsize=20)
fig.savefig(str(eval_dir_config.output_figure_dir / 'upliftGMV.png'))
# Out:
# /var/folders/5m/t2g98tcd7pzdwp7s3_zfjqym0000gp/T/ipykernel_54918/1512017961.py:31: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks().astype(int), fontsize=20)
# /var/folders/5m/t2g98tcd7pzdwp7s3_zfjqym0000gp/T/ipykernel_54918/1512017961.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks().astype(int), fontsize=20)
